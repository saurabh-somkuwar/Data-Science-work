# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\hp\\Desktop\\data\\titles.csv")

# %%
pd.re
# Out:
#                                           title  year
# 0                                The Rising Son  1990
# 1                       The Thousand Plane Raid  1969
# 2                              Crucea de piatra  1993
# 3                                       Country  2000
# 4                                    Gaiking II  2011
# 5                                   Medusa (IV)  2015
# 6                The Fresh Air Will Do You Good  2008
# 7                            Alex in Wonderland  1970
# 8                                    L'outsider  2016
# 9                        Do Outro Lado do Mundo  2008
# 10                                Slave by Name  2017
# 11                               The Abductress  2014
# 12                     Poka Makorer Ghar Bosoti  1996
# 13                                    Hi, Buddy  1943
# 14                              Los siete locos  1973
# 15                                   Panic Room  2002
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\hp'

# %%
os.chdir("C:\\Users\\hp\\Desktop\\data")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\hp\\Desktop\\data'

# %%
os.listdir()
# Out:
# ['cast.csv', 'release_dates.csv', 'titles.csv']

# %%
df1 = pd.read_csv("titles.csv")

# %%
c = df.head(20)

# %%
c.tail()
# Out:
#                      title  year
# 15              Panic Room  2002
# 16   Io sono un autarchico  1976
# 17  Shobhna's Seven Nights  2012
# 18              Mahapurush  1965
# 19        Maa Durga Shakti  1999

# %%
df.tail()
# Out:
#                                        title  year
# 230616                 Nobody Waved Good-bye  1964
# 230617                                 E yue  2005
# 230618                          Lakota Girls  2015
# 230619                        Kroniki domowe  1997
# 230620  Death in the Valley of Good and Evil  2018

# %%
df.head()
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2         Crucea de piatra  1993
# 3                  Country  2000
# 4               Gaiking II  2011

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.year
# Out:
# 0         1990
# 1         1969
# 2         1993
# 3         2000
# 4         2011
# 5         2015
# 6         2008
# 7         1970
# 8         2016
# 9         2008
# 10        2017
# 11        2014
# 12        1996
# 13        1943
# 14        1973
# 15        2002
# 16        1976
# 17        2012
# 18        1965
# 19        1999
# 20        1917
# 21        2009
# 22        1989
# 23        1993
# 24        2011
# 25        1916
# 26        1990
# 27        2001
# 28        2013
# 29        2012
#           ...
# 230591    2014
# 230592    2007
# 230593    1980
# 230594    1990
# 230595    2015
# 230596    1981
# 230597    2008
# 230598    1980
# 230599    2013
# 230600    2013
# 230601    1991
# 230602    1932
# 230603    1986
# 230604    1961
# 230605    1967
# 230606    2004
# 230607    1981
# 230608    2013
# 230609    2016
# 230610    2004
# 230611    1984
# 230612    2012
# 230613    2001
# 230614    1973
# 230615    1982
# 230616    1964
# 230617    2005
# ...

# %%
type(df['year'])
# Out:
# pandas.core.series.Series

# %%
len(df)
# Out:
# 230621

# %%
df.shape
# Out:
# (230621, 2)

# %%
c.shape
# Out:
# (20, 2)

# %%
c[c.year >2000]
# Out:
#                              title  year
# 4                       Gaiking II  2011
# 5                      Medusa (IV)  2015
# 6   The Fresh Air Will Do You Good  2008
# 8                       L'outsider  2016
# 9           Do Outro Lado do Mundo  2008
# 10                   Slave by Name  2017
# 11                  The Abductress  2014
# 15                      Panic Room  2002
# 17          Shobhna's Seven Nights  2012

# %%
c[(c['year']>2000 )| (c['year']<= 2015)]
# Out:
#                              title  year
# 0                   The Rising Son  1990
# 1          The Thousand Plane Raid  1969
# 2                 Crucea de piatra  1993
# 3                          Country  2000
# 4                       Gaiking II  2011
# 5                      Medusa (IV)  2015
# 6   The Fresh Air Will Do You Good  2008
# 7               Alex in Wonderland  1970
# 8                       L'outsider  2016
# 9           Do Outro Lado do Mundo  2008
# 10                   Slave by Name  2017
# 11                  The Abductress  2014
# 12        Poka Makorer Ghar Bosoti  1996
# 13                       Hi, Buddy  1943
# 14                 Los siete locos  1973
# 15                      Panic Room  2002
# 16           Io sono un autarchico  1976
# 17          Shobhna's Seven Nights  2012
# 18                      Mahapurush  1965
# 19                Maa Durga Shakti  1999

# %%
t = df

# %%
t.head()
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2         Crucea de piatra  1993
# 3                  Country  2000
# 4               Gaiking II  2011

# %%
t[t.title == "Star Wars"]
# Out:
#             title  year
# 163388  Star Wars  1977

# %%
t[t.title == "Macbeth"].sort_values("year",ascending = False)
# Out:
#           title  year
# 168225  Macbeth  2017
# 146810  Macbeth  2016
# 125469  Macbeth  2015
# 154409  Macbeth  2014
# 11539   Macbeth  2013
# 150447  Macbeth  2009
# 55416   Macbeth  2006
# 131922  Macbeth  2004
# 86470   Macbeth  2003
# 25430   Macbeth  1998
# 16930   Macbeth  1997
# 203220  Macbeth  1987
# 157917  Macbeth  1948
# 67313   Macbeth  1916
# 4162    Macbeth  1913

# %%
c = df
c[c.title == "Hamlet"]
# Out:
#          title  year
# 5969    Hamlet  1948
# 45010   Hamlet  1990
# 46365   Hamlet  1910
# 91506   Hamlet  1976
# 93696   Hamlet  1987
# 93894   Hamlet  2000
# 97869   Hamlet  1921
# 102208  Hamlet  2011
# 121837  Hamlet  1969
# 127468  Hamlet  1954
# 165217  Hamlet  1913
# 167748  Hamlet  2015
# 174816  Hamlet  2009
# 181662  Hamlet  1964
# 199837  Hamlet  1996
# 208366  Hamlet  1911
# 219855  Hamlet  1973
# 221923  Hamlet  2014

# %%
"The Golden Boot".startswith("The")
# Out:
# True

# %%
r = c.head(20)

# %%
e = r[r.title.str.startswith("The")]

# %%
e.title.str.len()
# Out:
# 0     14
# 1     23
# 6     30
# 11    14
# Name: title, dtype: int64

# %%
# %matplotlib inline
c.year.value_counts().sort_index().plot()

# %%
c.title.value_counts().sort_index().plot(kind = 'bar')
